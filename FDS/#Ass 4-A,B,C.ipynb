# %%
#Ass 4-A

# %%
#Q1. Generate a random array of 50 integers and display them using a line chart, scatter plot, histogram and box plot. 
#Apply appropriate color, labels and styling options.

import numpy as np
import matplotlib.pyplot as plt
x = np.random.randint (100, size=(50))
y = np.random.randint(100, size=(50))
plt.plot(x,y,color='blue', linestyle= 'dashed', marker='*', markerfacecolor='red')
plt.xlabel("X-axis", fontweight='bold', fontsize=10, color='blue')
plt.ylabel("Y-axis", fontweight='bold', fontsize=10, color='blue')
plt.title("Line Chart", fontweight='bold', fontsize=15, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randint (100, size=(50))
y = np.random.randint (100, size=(50))
plt.scatter(x,y, marker='^', edgecolor='r', s = 50, linewidths=2, color= 'yellow')
plt.xlabel("X-axis", fontweight = 'bold', fontsize=10, color='blue')
plt.ylabel("Y-axis", fontweight = 'bold', fontsize = 10 , color='blue')
plt.title("Scatter Chart", fontweight='bold', fontsize=15, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.random.randint (100, size=(50))
plt.hist (a,bins = 10, color='pink', edgecolor='blue')
plt.xlabel("X-axis", fontweight='bold', fontsize=10, color='blue')
plt.ylabel("Y-axis", fontweight='bold', fontsize=10, color='blue')
plt.title("Histogram Chart", fontweight = 'bold', fontsize=15, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a =np.random.randint (100, size=(50))
plt.boxplot(a)
plt.show()

# %%
# 2. Add two outliers to the above data and display the box plot.
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
data1 = np.random.normal(100,10,200)
data2 = np.random.normal(90,20,200)
data3 = np.random.normal(80,30,200) 
data4 = np.random.normal(70,40,200)
data = [data1, data2, data3, data4] 
plt.boxplot(data)
plt.show()

# %%
# 3.Create two lists, one representing subject names and the other representing marks obtained in those subjects. 
# Display the data in a pie chart and bar chart.

import numpy as np
import matplotlib.pyplot as plt
subjects = ['C', 'C++', 'JAVA', 'PYTHON', 'PHP', 'DSA', 'BT']
marks = [90,75,97,86,67,92,91]
plt.bar (subjects, marks, color='green', edgecolor='magenta', width=0.4)
plt.xlabel("Subjects", fontweight = 'bold', fontsize=10, color='blue')
plt.ylabel("Marks", fontweight = 'bold', fontsize=10, color='blue')
plt.title("Subjects with Marks", fontweight = 'bold', fontsize=15, color='red')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.pie (marks, labels=subjects)
plt.legend (subjects, title = "Subjects", loc='center right',bbox_to_anchor=(1,0.5))
plt.title("Subjects Vs Marks in pie chart",color='red')
plt.show()

# %%
#Q4 Write a Python program to create a Bar plot to get the frequency of the three species of the Iris data.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv("iris.csv")
x = iris["species"]
y = iris["sepal_length"]
plt.bar(x,y,color='green')
plt.xlabel("Classes", fontweight = 'bold', fontsize=10, color = 'blue')
plt.ylabel("Sepal_Length", fontweight='bold', fontsize=10, color='green')
plt.title("Iris Species Count")
plt.show()

# %%
#5. Write a Python program to create a Pie plot to get the frequency of the three species of the Iris data.

import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv("iris.csv")
iris['species'].value_counts().plot.pie (explode=[0.1,0.1,0.1], autopct='%1.1f%%')
plt.title("Iris Species %")
plt.show()

# %%
#6. Write a Python program to create a histogram of the three species of the Iris data.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a = pd.read_csv("iris.csv")
x = a["sepal_length"]
plt.hist(x, bins = 10, color='yellow', edgecolor='blue')
plt.xlabel("X-axis", fontweight = 'bold', fontsize=10, color='blue')
plt.ylabel("Y-axis", fontweight='bold', fontsize=10, color='blue')
plt.title("Histogram Chart", fontweight = 'bold', fontsize=15, color='red')
plt.show()

# %%
#Ass 4-B

# %%
# 1.Write a Python program to create a graph to find relationship between the # and petal width.
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv("iris.csv")
plt.plot(df['petal_length'], df['petal_width'], linestyle= 'dashed', color='red') 
plt.plot(df['sepal_length'], df['sepal_width'], linestyle= 'solid', color='green')
plt.title('Length Vs Width', fontweight = 'bold', fontsize=15, color='red')
plt.xlabel("length", fontweight = 'bold', fontsize=10, color='blue') 
plt.ylabel("width", fontweight = 'bold', fontsize=10, color='blue')
plt.legend(['Petal', 'Sepal'])
plt.show()

# %%
#2. Write a Python program to draw scatter plots to compare two features of t
# dataset.
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("iris.csv")
sns.FacetGrid (df, hue='species').map(plt.scatter, 'sepal_length', 'petal_length')
plt.show()

# %%
# 3.Write a Python program to create box plots to see how each feature i.e. s # Sepal Width, Petal Length, Petal Width are distributed across the three spe
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("iris.csv")
new_data = data[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
# print(new_data.head())
new_data.boxplot()
# Out:
# <AxesSubplot:>

# %%
#Ass 4-C

# %%
# 1. Write a Python program to create a pairplot of the iris data set and chec
# species seems to be the most separable.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv("iris.csv")
g= sns.jointplot (x="sepal_length", y="sepal_width", data=iris, kind="kde", color='Purple')
g.plot_joint (plt.scatter, c="w", s=40, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels ("$SepalLength (Cm)$", "$SepalWidth (Cm)$")
plt.show()
g = sns.jointplot (x="petal_length", y="petal_width", data=iris, kind="kde", color='Purple')
g.plot_joint (plt.scatter, c="w", s=40, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels ("$PetalLength (Cm)$", "$PetalWidth (Cm)$")
plt.show()

# %%
#2. Write a Python program to generate a box plot to show the Interquartile range and outliers for the three species 
# for each feature.


import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = datasets.load_iris()
iris_data = pd.DataFrame(iris.data, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
iris_target = pd.DataFrame(data=iris.target, columns=['species'])
iris_df = pd.concat([iris_data, iris_target], axis=1)

# Map species codes to species names
iris_df['species_name'] = iris_df['species'].map({0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})

# Filter data for each species
setosa_petal_length = iris_df[iris_df['species_name'] == 'Setosa']['petal_length']
versicolor_petal_length = iris_df[iris_df['species_name'] == 'Versicolor']['petal_length']
virginica_petal_length = iris_df[iris_df['species_name'] == 'Virginica']['petal_length']

# Create a boxplot
fig, ax = plt.subplots(figsize=(12, 7))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.yaxis.set_ticks_position("none")
ax.grid(color='grey', axis='y', linestyle='--', linewidth=0.8, alpha=0.5)
ax.set_title('Distribution of petal length by species')

# Create a dataset for boxplot
dataset = [setosa_petal_length, versicolor_petal_length, virginica_petal_length]
labels = iris_df['species_name'].unique()

# Create the boxplot
ax.boxplot(dataset, labels=labels)
plt.show()

# %%
# 3. Write a Python program to create a join plot using "kde" to describe ind # distributions on the same plot between Sepal Length and Sepal width. Note: # density estimation (kde) procedure visualizes a bivariate distribution. In # kind of plot is shown with a contour plot and is available as a style in jo
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

iris = pd.read_csv("iris.csv")
fig = sns.jointplot(x='sepal_length', y='sepal_width',data=iris, kind='kde', color='blue')
plt.show()
