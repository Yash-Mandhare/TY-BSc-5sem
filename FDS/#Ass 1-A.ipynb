# %%
#Ass 1-A

# %%
import pandas as pd

# %%
# Write a Python program to create a dataframe containing columns name, age and percentage. Add 10 rows to the dataframe. 
# View the dataframe.
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[0] = ['Ankit',18,67.8]
df.loc[1] = ['Maya',16,70]
df.loc[2] = ['Pratiksha',20,80]
df.loc[3] = ['Pratik',21,90]
df.loc[4] = ['Rajesh',22,77]
df.loc[5] = ['Pravin',23,68]
df.loc[6] = ['Rupak',14,76]
df.loc[7] = ['Sohel',26,88]
df.loc[8] = ['Rohit',54,67]
df.loc[9] = ['Pranjal',45,78]
print(df)
# Out:
#         Name  Age  Percentage
# 0      Ankit   18        67.8
# 1       Maya   16        70.0
# 2  Pratiksha   20        80.0
# 3     Pratik   21        90.0
# 4     Rajesh   22        77.0
# 5     Pravin   23        68.0
# 6      Rupak   14        76.0
# 7      Sohel   26        88.0
# 8      Rohit   54        67.0
# 9    Pranjal   45        78.0

# %%
df
# Out:
#         Name  Age  Percentage
# 0      Ankit   18        67.8
# 1       Maya   16        70.0
# 2  Pratiksha   20        80.0
# 3     Pratik   21        90.0
# 4     Rajesh   22        77.0
# 5     Pravin   23        68.0
# 6      Rupak   14        76.0
# 7      Sohel   26        88.0
# 8      Rohit   54        67.0
# 9    Pranjal   45        78.0

# %%
# Write a Python program to print the shape, number of rows-columns, data types, feature names and the description of the data
df.shape
# Out:
# (10, 3)

# %%
#number of rows and columns.
df.loc[:]
# Out:
#         Name  Age  Percentage
# 0      Ankit   18        67.8
# 1       Maya   16        70.0
# 2  Pratiksha   20        80.0
# 3     Pratik   21        90.0
# 4     Rajesh   22        77.0
# 5     Pravin   23        68.0
# 6      Rupak   14        76.0
# 7      Sohel   26        88.0
# 8      Rohit   54        67.0
# 9    Pranjal   45        78.0

# %%
#data types
df.dtypes
# Out:
# Name           object
# Age             int64
# Percentage    float64
# dtype: object

# %%
#description of data
df.describe()
# Out:
#              Age  Percentage
# count  10.000000   10.000000
# mean   25.900000   76.180000
# std    13.076272    8.225408
# min    14.000000   67.000000
# 25%    18.500000   68.500000
# 50%    21.500000   76.500000
# 75%    25.250000   79.500000
# max    54.000000   90.000000

# %%
#information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         10 non-null     int64
#  2   Percentage  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
# Write a Python program to view basic statistical details of the data.
df.describe()
# Out:
#              Age  Percentage
# count  10.000000   10.000000
# mean   25.900000   76.180000
# std    13.076272    8.225408
# min    14.000000   67.000000
# 25%    18.500000   68.500000
# 50%    21.500000   76.500000
# 75%    25.250000   79.500000
# max    54.000000   90.000000

# %%
# Write a Python program to Add 5 rows with duplicate values and missing values. Add a column'remarks' with empty values. 
# Display the data
df.loc[10] = ['Pravin',23,68]
df.loc[11] = ['Pratiksha',20,80]
df.loc[12] = [None,None,None]
df.loc[13] = ['Rajesh',22,None]
df["Remarks"] = None

# %%
df
# Out:
#          Name   Age Percentage Remarks
# 0       Ankit    18       67.8    None
# 1        Maya    16       70.0    None
# 2   Pratiksha    20       80.0    None
# 3      Pratik    21       90.0    None
# 4      Rajesh    22       77.0    None
# 5      Pravin    23       68.0    None
# 6       Rupak    14       76.0    None
# 7       Sohel    26       88.0    None
# 8       Rohit    54       67.0    None
# 9     Pranjal    45       78.0    None
# 10     Pravin    23       68.0    None
# 11  Pratiksha    20       80.0    None
# 12       None  None        NaN    None
# 13     Rajesh    22       None    None

# %%
#Write a Python program to get the number of observations, missing values and duplicate values.
df.drop(columns=["Remarks"])
# Out:
#          Name   Age Percentage
# 0       Ankit    18       67.8
# 1        Maya    16       70.0
# 2   Pratiksha    20       80.0
# 3      Pratik    21       90.0
# 4      Rajesh    22       77.0
# 5      Pravin    23       68.0
# 6       Rupak    14       76.0
# 7       Sohel    26       88.0
# 8       Rohit    54       67.0
# 9     Pranjal    45       78.0
# 10     Pravin    23       68.0
# 11  Pratiksha    20       80.0
# 12       None  None        NaN
# 13     Rajesh    22       None

# %%
#question number 5 duplicate values
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# dtype: bool

# %%
df.drop(columns = 'Remarks', axis=1, inplace=True)
df
# Out:
#          Name   Age Percentage
# 0       Ankit    18       67.8
# 1        Maya    16       70.0
# 2   Pratiksha    20       80.0
# 3      Pratik    21       90.0
# 4      Rajesh    22       77.0
# 5      Pravin    23       68.0
# 6       Rupak    14       76.0
# 7       Sohel    26       88.0
# 8       Rohit    54       67.0
# 9     Pranjal    45       78.0
# 10     Pravin    23       68.0
# 11  Pratiksha    20       80.0
# 12       None  None        NaN
# 13     Rajesh    22       None

# %%
# Write a Python program to generate a line plot of name vs percentage

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(df.Age,df.Percentage)
plt.show()

# %%
# Write a Python program to generate a scatter plot of name vs percentage
df.plot(kind="scatter",x="Age", y="Percentage")
df.plot.scatter(x="Age",y="Percentage")
plt.scatter(df['Age'], df['Percentage'])
plt.show()

# %%
#option 2
import numpy as np
import matplotlib.pyplot as plt
plt.xlabel("Name")
plt.ylabel("Percentage")
plt.title("Name vs Percentage")
name = np.array(["Ana", "James", "Joe", "Sam", "Mary"], dtype=str)
percentage = np.array([23, 80, 45, 60, 90], dtype=int)
plt.scatter(name, percentage, c="r")
plt.show()
